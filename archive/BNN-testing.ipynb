# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_probability as tfp
import tf_keras

# %%
# ------ DATA GENERATION ------

# %%
np.random.seed(42+1)

X_train = np.hstack([0.1 * np.random.randn(10000), 0.6 + 0.2 * np.random.randn(0), 1.2 + 0.1 * np.random.randn(10000)])
noise = 0.02 * np.random.randn(X_train.shape[0])
y_train = X_train + 0.3 * np.sin(2 * np.pi * (X_train + noise)) + 0.3 * np.sin(4 * np.pi * (X_train + noise)) + noise

x_true = np.linspace(-1, 2, 1000)
y_true = x_true + 0.3 * np.sin(2 * np.pi * x_true) + 0.3 * np.sin(4 * np.pi * x_true)

xlims = [-1, 2]
ylims = [-1.5, 2.5]

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x_true, y_true, 'b-', linewidth=3, label="True function", alpha=0.8)
ax.plot(X_train,y_train, 'ko', markersize=4, label="Observations", alpha=0.4)
ax.set_xlim(xlims)
ax.set_ylim(ylims)
ax.set_xlabel("X", fontsize=15)
ax.set_ylabel("Y", fontsize=15)
ax.legend(loc=4, fontsize=15, frameon=False)

plt.show()

# %%
plt.hist(X_train, bins=np.linspace(-0.3, 1.8, 30))
plt.show()

# %%
# ------ NON-BAYESIAN SINGLE OUTPUT ------

# %%
model = tf_keras.Sequential([
    tf_keras.layers.Dense(128, activation='relu', input_shape=(1,)),
    tf_keras.layers.Dense(128, activation='relu'),
    tf_keras.layers.Dense(128, activation='relu'),
    tf_keras.layers.Dense(1)
])

model.compile(optimizer=tf_keras.optimizers.Adam(learning_rate=0.001), loss="MSE")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               256
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 33409 (130.50 KB)
# Trainable params: 33409 (130.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
x_test = np.linspace(-0.5, 1.5, 1000)
y_test = x_test + 0.3 * np.sin(2 * np.pi * x_test) + 0.3 * np.sin(4 * np.pi * x_test)

history = model.fit(X_train,y_train, validation_data=(x_test, y_test), epochs=40, verbose=1)
# Out:
# Epoch 1/40
# 625/625 [==============================] - 0s 354us/step - loss: 0.0430 - val_loss: 0.1282
# Epoch 2/40
# 625/625 [==============================] - 0s 268us/step - loss: 0.0258 - val_loss: 0.1381
# Epoch 3/40
# 625/625 [==============================] - 0s 283us/step - loss: 0.0175 - val_loss: 0.0937
# Epoch 4/40
# 625/625 [==============================] - 0s 264us/step - loss: 0.0100 - val_loss: 0.0268
# Epoch 5/40
# 625/625 [==============================] - 0s 280us/step - loss: 0.0077 - val_loss: 0.0150
# Epoch 6/40
# 625/625 [==============================] - 0s 271us/step - loss: 0.0081 - val_loss: 0.0197
# Epoch 7/40
# 625/625 [==============================] - 0s 273us/step - loss: 0.0077 - val_loss: 0.0180
# Epoch 8/40
# 625/625 [==============================] - 0s 266us/step - loss: 0.0077 - val_loss: 0.0180
# Epoch 9/40
# 625/625 [==============================] - 0s 266us/step - loss: 0.0074 - val_loss: 0.0188
# Epoch 10/40
# 625/625 [==============================] - 0s 270us/step - loss: 0.0074 - val_loss: 0.0193
# Epoch 11/40
# 625/625 [==============================] - 0s 260us/step - loss: 0.0074 - val_loss: 0.0211
# Epoch 12/40
# 625/625 [==============================] - 0s 280us/step - loss: 0.0074 - val_loss: 0.0217
# Epoch 13/40
# 625/625 [==============================] - 0s 266us/step - loss: 0.0073 - val_loss: 0.0198
# Epoch 14/40
# 625/625 [==============================] - 0s 271us/step - loss: 0.0073 - val_loss: 0.0180
# Epoch 15/40
# 625/625 [==============================] - 0s 267us/step - loss: 0.0073 - val_loss: 0.0188
# Epoch 16/40
# 625/625 [==============================] - 0s 269us/step - loss: 0.0073 - val_loss: 0.0207
# Epoch 17/40
# 625/625 [==============================] - 0s 268us/step - loss: 0.0072 - val_loss: 0.0187
# Epoch 18/40
# 625/625 [==============================] - 0s 275us/step - loss: 0.0071 - val_loss: 0.0154
# Epoch 19/40
# 625/625 [==============================] - 0s 266us/step - loss: 0.0071 - val_loss: 0.0169
# Epoch 20/40
# 625/625 [==============================] - 0s 271us/step - loss: 0.0072 - val_loss: 0.0151
# Epoch 21/40
# 625/625 [==============================] - 0s 273us/step - loss: 0.0072 - val_loss: 0.0167
# Epoch 22/40
# 625/625 [==============================] - 0s 268us/step - loss: 0.0072 - val_loss: 0.0161
# Epoch 23/40
# 625/625 [==============================] - 0s 261us/step - loss: 0.0071 - val_loss: 0.0160
# Epoch 24/40
# 625/625 [==============================] - 0s 262us/step - loss: 0.0070 - val_loss: 0.0149
# Epoch 25/40
# 625/625 [==============================] - 0s 265us/step - loss: 0.0071 - val_loss: 0.0149
# Epoch 26/40
# 625/625 [==============================] - 0s 274us/step - loss: 0.0072 - val_loss: 0.0155
# Epoch 27/40
# 625/625 [==============================] - 0s 268us/step - loss: 0.0070 - val_loss: 0.0185
# Epoch 28/40
# 625/625 [==============================] - 0s 260us/step - loss: 0.0071 - val_loss: 0.0151
# Epoch 29/40
# 625/625 [==============================] - 0s 263us/step - loss: 0.0069 - val_loss: 0.0150
# Epoch 30/40
# 625/625 [==============================] - 0s 260us/step - loss: 0.0071 - val_loss: 0.0146
# Epoch 31/40
# 625/625 [==============================] - 0s 269us/step - loss: 0.0069 - val_loss: 0.0156
# Epoch 32/40
# 625/625 [==============================] - 0s 262us/step - loss: 0.0070 - val_loss: 0.0148
# Epoch 33/40
# 625/625 [==============================] - 0s 258us/step - loss: 0.0069 - val_loss: 0.0146
# Epoch 34/40
# 625/625 [==============================] - 0s 248us/step - loss: 0.0070 - val_loss: 0.0173
# Epoch 35/40
# 625/625 [==============================] - 0s 261us/step - loss: 0.0070 - val_loss: 0.0112
# Epoch 36/40
# 625/625 [==============================] - 0s 272us/step - loss: 0.0070 - val_loss: 0.0115
# Epoch 37/40
# 625/625 [==============================] - 0s 271us/step - loss: 0.0070 - val_loss: 0.0111
# Epoch 38/40
# 625/625 [==============================] - 0s 267us/step - loss: 0.0070 - val_loss: 0.0114
# Epoch 39/40
# 625/625 [==============================] - 0s 273us/step - loss: 0.0069 - val_loss: 0.0124
# Epoch 40/40
# 625/625 [==============================] - 0s 270us/step - loss: 0.0070 - val_loss: 0.0124

# %%
x_test = np.linspace(-1, 2, 1000)
y_test = x_test + 0.3 * np.sin(2 * np.pi * x_test) + 0.3 * np.sin(4 * np.pi * x_test)
y_pred = model(x_test)


import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.plot(X_train, y_train, 'o', label='Train data', alpha=0.1)
plt.plot(x_test, y_pred, 'b', label='Predictive mean')
plt.plot(x_test, y_test, 'r', linewidth=3, label="True function", alpha=0.5)
plt.ylim(-1.5,2)
plt.xlim(-1, 2)
plt.legend()
plt.show()

# %%
# ------ NON-BAYESIAN GAUSSIAN MIXTURE ------

# %%
event_shape = [1]
params_size = tfp.layers.MixtureNormal.params_size(2, event_shape)

model = tf_keras.Sequential([
    tf_keras.layers.Dense(128, activation='relu', input_shape=(1,)),
    tf_keras.layers.Dense(128, activation='relu'),
    tf_keras.layers.Dense(128, activation='relu'),
    tf_keras.layers.Dense(params_size),
    tfp.layers.MixtureNormal(2, event_shape)
])

def negloglik(y_true, y_pred):
    return -y_pred.log_prob(y_true)

model.compile(optimizer=tf_keras.optimizers.Adam(learning_rate=0.001), loss=negloglik)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 128)               256
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dense_7 (Dense)             (None, 6)                 774
#
#  mixture_normal (MixtureNor  ((None, 1),               0
#  mal)                         (None, 1))
#
# =================================================================
# Total params: 34054 (133.02 KB)
# Trainable params: 34054 (133.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
x_test = np.linspace(-0.5, 1.5, 1000)
y_test = x_test + 0.3 * np.sin(2 * np.pi * x_test) + 0.3 * np.sin(4 * np.pi * x_test)

history = model.fit(X_train,y_train, validation_data=(x_test, y_test), epochs=40, verbose=1)
# Out:
# Epoch 1/40
# 625/625 [==============================] - 1s 527us/step - loss: -0.4260 - val_loss: 0.9844
# Epoch 2/40
# 625/625 [==============================] - 0s 308us/step - loss: -0.6045 - val_loss: 0.7759
# Epoch 3/40
# 625/625 [==============================] - 0s 303us/step - loss: -0.6517 - val_loss: 1.0289
# Epoch 4/40
# 625/625 [==============================] - 0s 314us/step - loss: -0.7115 - val_loss: 1.5300
# Epoch 5/40
# 625/625 [==============================] - 0s 309us/step - loss: -0.8333 - val_loss: 0.2422
# Epoch 6/40
# 625/625 [==============================] - 0s 306us/step - loss: -1.0368 - val_loss: -0.0653
# Epoch 7/40
# 625/625 [==============================] - 0s 315us/step - loss: -1.1281 - val_loss: -0.3095
# Epoch 8/40
# 625/625 [==============================] - 0s 306us/step - loss: -1.1964 - val_loss: -0.6158
# Epoch 9/40
# 625/625 [==============================] - 0s 310us/step - loss: -1.2359 - val_loss: -0.9133
# Epoch 10/40
# 625/625 [==============================] - 0s 312us/step - loss: -1.2488 - val_loss: -0.9291
# Epoch 11/40
# 625/625 [==============================] - 0s 324us/step - loss: -1.2538 - val_loss: -0.8982
# Epoch 12/40
# 625/625 [==============================] - 0s 306us/step - loss: -1.2740 - val_loss: -0.9588
# Epoch 13/40
# 625/625 [==============================] - 0s 309us/step - loss: -1.2497 - val_loss: -0.9610
# Epoch 14/40
# 625/625 [==============================] - 0s 297us/step - loss: -1.2878 - val_loss: -1.0045
# Epoch 15/40
# 625/625 [==============================] - 0s 303us/step - loss: -1.2853 - val_loss: -1.0926
# Epoch 16/40
# 625/625 [==============================] - 0s 289us/step - loss: -1.2847 - val_loss: -1.0460
# Epoch 17/40
# 625/625 [==============================] - 0s 298us/step - loss: -1.3099 - val_loss: -1.0874
# Epoch 18/40
# 625/625 [==============================] - 0s 310us/step - loss: -1.3139 - val_loss: -1.0803
# Epoch 19/40
# 625/625 [==============================] - 0s 310us/step - loss: -1.3135 - val_loss: -1.1419
# Epoch 20/40
# 625/625 [==============================] - 0s 322us/step - loss: -1.3199 - val_loss: -0.9554
# Epoch 21/40
# 625/625 [==============================] - 0s 302us/step - loss: -1.3345 - val_loss: -1.0846
# Epoch 22/40
# 625/625 [==============================] - 0s 305us/step - loss: -1.3302 - val_loss: -1.0055
# Epoch 23/40
# 625/625 [==============================] - 0s 302us/step - loss: -1.3419 - val_loss: -1.1573
# Epoch 24/40
# 625/625 [==============================] - 0s 304us/step - loss: -1.3426 - val_loss: -0.9705
# Epoch 25/40
# 625/625 [==============================] - 0s 305us/step - loss: -1.3453 - val_loss: -1.0894
# Epoch 26/40
# 625/625 [==============================] - 0s 308us/step - loss: -1.3488 - val_loss: -1.1014
# Epoch 27/40
# 625/625 [==============================] - 0s 309us/step - loss: -1.3553 - val_loss: -1.0246
# Epoch 28/40
# 625/625 [==============================] - 0s 292us/step - loss: -1.3499 - val_loss: -1.0805
# Epoch 29/40
# 625/625 [==============================] - 0s 310us/step - loss: -1.3592 - val_loss: -1.0135
# Epoch 30/40
# 625/625 [==============================] - 0s 316us/step - loss: -1.3637 - val_loss: -1.1648
# Epoch 31/40
# 625/625 [==============================] - 0s 296us/step - loss: -1.3701 - val_loss: -0.8067
# Epoch 32/40
# 625/625 [==============================] - 0s 295us/step - loss: -1.3579 - val_loss: -0.9369
# Epoch 33/40
# 625/625 [==============================] - 0s 306us/step - loss: -1.3659 - val_loss: -0.8959
# Epoch 34/40
# 625/625 [==============================] - 0s 300us/step - loss: -1.3789 - val_loss: -0.6988
# Epoch 35/40
# 625/625 [==============================] - 0s 302us/step - loss: -1.3684 - val_loss: -0.6319
# Epoch 36/40
# 625/625 [==============================] - 0s 303us/step - loss: -1.3800 - val_loss: -0.3529
# Epoch 37/40
# 625/625 [==============================] - 0s 310us/step - loss: -1.3755 - val_loss: -0.7413
# Epoch 38/40
# 625/625 [==============================] - 0s 301us/step - loss: -1.3723 - val_loss: -0.4654
# Epoch 39/40
# 625/625 [==============================] - 0s 297us/step - loss: -1.3843 - val_loss: 0.5322
# Epoch 40/40
# 625/625 [==============================] - 0s 307us/step - loss: -1.3763 - val_loss: 1.0694

# %%
x_test = np.linspace(-1, 2, 1000)
y_test = x_test + 0.3 * np.sin(2 * np.pi * x_test) + 0.3 * np.sin(4 * np.pi * x_test)
y_dist = model(x_test)
y_pred = y_dist.mean().numpy()
y_std = y_dist.stddev().numpy()

import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.plot(X_train, y_train, 'o', label='Train data', alpha=0.05)
plt.plot(x_test, y_pred, 'b', label='Predictive mean')
plt.plot(x_test, y_test, 'r', linewidth=3, label="True function", alpha=0.5)
plt.fill_between(x_test.flatten(),
                 (y_pred - y_std).reshape(-1),
                 (y_pred + y_std).reshape(-1),
                 color='blue', alpha=0.2, label='±σ')
plt.ylim(-1.5,2)
plt.xlim(-1, 2)
plt.legend()
plt.show()
# Out:
# 2025-08-26 09:29:58.854780: E tensorflow/core/util/util.cc:131] oneDNN supports DT_INT32 only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.

# %%
# ------ BAYESIAN SINGLE OUTPUT ------

# %%
tfd = tfp.distributions
tfpl = tfp.layers

batch_num = int(X_train.shape[0] / 128)

scale = X_train.shape[0]

norm_layer = tf_keras.layers.Normalization(input_shape=(1,))
norm_layer.adapt(X_train.reshape(-1,1))

activation = "relu"
model = tf_keras.Sequential([
    norm_layer,
    tfpl.DenseFlipout(128, activation=activation,
                      kernel_divergence_fn=lambda q,p,ignore: tfp.distributions.kl_divergence(q, p) / scale,
                      bias_divergence_fn=lambda q,p,ignore: tfp.distributions.kl_divergence(q, p) / scale),
    tfpl.DenseFlipout(128, activation=activation,
                      kernel_divergence_fn=lambda q,p,ignore: tfp.distributions.kl_divergence(q, p) / scale,
                      bias_divergence_fn=lambda q,p,ignore: tfp.distributions.kl_divergence(q, p) / scale),
    tfpl.DenseFlipout(128, activation=activation,
                      kernel_divergence_fn=lambda q,p,ignore: tfp.distributions.kl_divergence(q, p) / scale,
                      bias_divergence_fn=lambda q,p,ignore: tfp.distributions.kl_divergence(q, p) / scale),
    tf_keras.layers.Dense(1)
])


boundaries = [50 * batch_num]
values = [0.001, 0.0001]
learning_schedule = tf_keras.optimizers.schedules.PiecewiseConstantDecay(
    boundaries, values)

model.compile(optimizer=tf_keras.optimizers.Adam(learning_rate=learning_schedule), loss="MSE")
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_2 (Normaliza  (None, 1)                 3
#  tion)
#
#  dense_flipout_6 (DenseFlip  (None, 128)               384
#  out)
#
#  dense_flipout_7 (DenseFlip  (None, 128)               32896
#  out)
#
#  dense_flipout_8 (DenseFlip  (None, 128)               32896
#  out)
#
#  dense_10 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 66308 (259.02 KB)
# Trainable params: 66305 (259.00 KB)
# Non-trainable params: 3 (16.00 Byte)
# _________________________________________________________________
# /home/kdrabicki/anaconda3/envs/cpu_env/lib/python3.12/site-packages/tensorflow_probability/python/layers/util.py:99: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   loc = add_variable_fn(
# /home/kdrabicki/anaconda3/envs/cpu_env/lib/python3.12/site-packages/tf_keras/src/initializers/initializers.py:121: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# /home/kdrabicki/anaconda3/envs/cpu_env/lib/python3.12/site-packages/tensorflow_probability/python/layers/util.py:109: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   untransformed_scale = add_variable_fn(

# %%
x_test = np.linspace(-0.5, 1.5, 1000)
y_test = x_test + 0.3 * np.sin(2 * np.pi * x_test) + 0.3 * np.sin(4 * np.pi * x_test)


loss_log_dir = "../logs/fit/loss/BNN"
history = model.fit(X_train,y_train, validation_data=(x_test, y_test), epochs=1000, verbose=1, batch_size=128,
                    callbacks=[tf_keras.callbacks.TensorBoard(log_dir=loss_log_dir, histogram_freq=1), tf_keras.callbacks.EarlyStopping(monitor='val_loss',
                                                                                                                                        mode='min',
                                                                                                                                        patience=30,
                                                                                                                                        verbose=1,
                                                                                                                                        start_from_epoch=100,
                                                                                                                                        restore_best_weights=True)])
# Out:
# Epoch 1/1000
# 157/157 [==============================] - 1s 2ms/step - loss: 4.1459 - val_loss: 4.2048
# Epoch 2/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 3.8639 - val_loss: 3.9304
# Epoch 3/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 3.6322 - val_loss: 3.7142
# Epoch 4/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 3.4015 - val_loss: 3.4407
# Epoch 5/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 3.1732 - val_loss: 3.2172
# Epoch 6/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 2.9485 - val_loss: 2.9878
# Epoch 7/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 2.7277 - val_loss: 2.7625
# Epoch 8/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 2.5109 - val_loss: 2.5560
# Epoch 9/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 2.2991 - val_loss: 2.3280
# Epoch 10/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 2.0930 - val_loss: 2.1113
# Epoch 11/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.8937 - val_loss: 1.9127
# Epoch 12/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.7017 - val_loss: 1.7169
# Epoch 13/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.5174 - val_loss: 1.5260
# Epoch 14/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.3435 - val_loss: 1.3562
# Epoch 15/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.1792 - val_loss: 1.1925
# Epoch 16/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.0253 - val_loss: 1.0254
# Epoch 17/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.8850 - val_loss: 0.8915
# Epoch 18/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.7561 - val_loss: 0.7797
# Epoch 19/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.6410 - val_loss: 0.6525
# Epoch 20/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.5391 - val_loss: 0.5521
# Epoch 21/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.4495 - val_loss: 0.4812
# Epoch 22/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.3733 - val_loss: 0.3984
# Epoch 23/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.3084 - val_loss: 0.3322
# Epoch 24/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.2555 - val_loss: 0.2904
# Epoch 25/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.2115 - val_loss: 0.2509
# Epoch 26/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.1765 - val_loss: 0.2060
# Epoch 27/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.1486 - val_loss: 0.1919
# Epoch 28/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.1267 - val_loss: 0.1764
# Epoch 29/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.1098 - val_loss: 0.1514
# Epoch 30/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0967 - val_loss: 0.1398
# Epoch 31/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0865 - val_loss: 0.1295
# Epoch 32/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0781 - val_loss: 0.1325
# Epoch 33/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0712 - val_loss: 0.1220
# Epoch 34/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0667 - val_loss: 0.0965
# Epoch 35/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0623 - val_loss: 0.1155
# Epoch 36/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0585 - val_loss: 0.1089
# Epoch 37/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0555 - val_loss: 0.1066
# Epoch 38/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0522 - val_loss: 0.0951
# Epoch 39/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0501 - val_loss: 0.0907
# Epoch 40/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0478 - val_loss: 0.0873
# Epoch 41/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0465 - val_loss: 0.0904
# Epoch 42/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0445 - val_loss: 0.0896
# Epoch 43/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0433 - val_loss: 0.0944
# Epoch 44/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0418 - val_loss: 0.0920
# Epoch 45/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0409 - val_loss: 0.0836
# Epoch 46/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0396 - val_loss: 0.0852
# Epoch 47/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0390 - val_loss: 0.0835
# Epoch 48/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0382 - val_loss: 0.0804
# Epoch 49/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0371 - val_loss: 0.0823
# Epoch 50/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0365 - val_loss: 0.0726
# Epoch 51/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0362 - val_loss: 0.0763
# Epoch 52/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0360 - val_loss: 0.0800
# Epoch 53/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0361 - val_loss: 0.0778
# Epoch 54/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0357 - val_loss: 0.0773
# Epoch 55/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0358 - val_loss: 0.0841
# Epoch 56/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0357 - val_loss: 0.0781
# Epoch 57/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0358 - val_loss: 0.0895
# Epoch 58/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0358 - val_loss: 0.0739
# Epoch 59/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0358 - val_loss: 0.0774
# Epoch 60/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0353 - val_loss: 0.0752
# Epoch 61/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0353 - val_loss: 0.0831
# Epoch 62/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0353 - val_loss: 0.0780
# Epoch 63/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0353 - val_loss: 0.0732
# Epoch 64/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0348 - val_loss: 0.0814
# Epoch 65/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0351 - val_loss: 0.0736
# Epoch 66/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0349 - val_loss: 0.0735
# Epoch 67/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0348 - val_loss: 0.0696
# Epoch 68/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0347 - val_loss: 0.0826
# Epoch 69/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0344 - val_loss: 0.0747
# Epoch 70/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0345 - val_loss: 0.0731
# Epoch 71/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0347 - val_loss: 0.0851
# Epoch 72/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0346 - val_loss: 0.0771
# Epoch 73/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0342 - val_loss: 0.0733
# Epoch 74/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0342 - val_loss: 0.0761
# Epoch 75/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0343 - val_loss: 0.0820
# Epoch 76/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0342 - val_loss: 0.0718
# Epoch 77/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0342 - val_loss: 0.0774
# Epoch 78/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0340 - val_loss: 0.0932
# Epoch 79/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0341 - val_loss: 0.0709
# Epoch 80/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0338 - val_loss: 0.0744
# Epoch 81/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0338 - val_loss: 0.0778
# Epoch 82/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0339 - val_loss: 0.0671
# Epoch 83/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0338 - val_loss: 0.0757
# Epoch 84/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0334 - val_loss: 0.0687
# Epoch 85/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0335 - val_loss: 0.0806
# Epoch 86/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0335 - val_loss: 0.0727
# Epoch 87/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0338 - val_loss: 0.0662
# Epoch 88/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0334 - val_loss: 0.0676
# Epoch 89/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0334 - val_loss: 0.0718
# Epoch 90/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0335 - val_loss: 0.0661
# Epoch 91/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0331 - val_loss: 0.0697
# Epoch 92/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0329 - val_loss: 0.0686
# Epoch 93/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0331 - val_loss: 0.0693
# Epoch 94/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0329 - val_loss: 0.0670
# Epoch 95/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0329 - val_loss: 0.0732
# Epoch 96/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0328 - val_loss: 0.0644
# Epoch 97/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0326 - val_loss: 0.0706
# Epoch 98/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0332 - val_loss: 0.0728
# Epoch 99/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0327 - val_loss: 0.0656
# Epoch 100/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0326 - val_loss: 0.0736
# Epoch 101/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0325 - val_loss: 0.0662
# Epoch 102/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0324 - val_loss: 0.0621
# Epoch 103/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0327 - val_loss: 0.0698
# Epoch 104/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0325 - val_loss: 0.0705
# Epoch 105/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0322 - val_loss: 0.0690
# Epoch 106/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0326 - val_loss: 0.0648
# Epoch 107/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0322 - val_loss: 0.0662
# Epoch 108/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0320 - val_loss: 0.0721
# Epoch 109/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0327 - val_loss: 0.0625
# Epoch 110/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0320 - val_loss: 0.0738
# Epoch 111/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0322 - val_loss: 0.0675
# Epoch 112/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0321 - val_loss: 0.0769
# Epoch 113/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0320 - val_loss: 0.0641
# Epoch 114/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0320 - val_loss: 0.0690
# Epoch 115/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0319 - val_loss: 0.0724
# Epoch 116/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0319 - val_loss: 0.0744
# Epoch 117/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0318 - val_loss: 0.0650
# Epoch 118/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0318 - val_loss: 0.0679
# Epoch 119/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0317 - val_loss: 0.0691
# Epoch 120/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0315 - val_loss: 0.0731
# Epoch 121/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0317 - val_loss: 0.0668
# Epoch 122/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0318 - val_loss: 0.0656
# Epoch 123/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0316 - val_loss: 0.0684
# Epoch 124/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0316 - val_loss: 0.0658
# Epoch 125/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0315 - val_loss: 0.0700
# Epoch 126/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0314 - val_loss: 0.0603
# Epoch 127/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0315 - val_loss: 0.0721
# Epoch 128/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0318 - val_loss: 0.0655
# Epoch 129/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0313 - val_loss: 0.0711
# Epoch 130/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0313 - val_loss: 0.0677
# Epoch 131/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0312 - val_loss: 0.0718
# Epoch 132/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0313 - val_loss: 0.0660
# Epoch 133/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0313 - val_loss: 0.0619
# Epoch 134/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0312 - val_loss: 0.0666
# Epoch 135/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0311 - val_loss: 0.0721
# Epoch 136/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0314 - val_loss: 0.0632
# Epoch 137/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0309 - val_loss: 0.0634
# Epoch 138/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0310 - val_loss: 0.0606
# Epoch 139/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0310 - val_loss: 0.0699
# Epoch 140/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0309 - val_loss: 0.0616
# Epoch 141/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0310 - val_loss: 0.0731
# Epoch 142/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0309 - val_loss: 0.0807
# Epoch 143/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0310 - val_loss: 0.0682
# Epoch 144/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0309 - val_loss: 0.0601
# Epoch 145/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0310 - val_loss: 0.0688
# Epoch 146/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0308 - val_loss: 0.0634
# Epoch 147/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0307 - val_loss: 0.0702
# Epoch 148/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0307 - val_loss: 0.0644
# Epoch 149/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0307 - val_loss: 0.0648
# Epoch 150/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0307 - val_loss: 0.0713
# Epoch 151/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0307 - val_loss: 0.0627
# Epoch 152/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0310 - val_loss: 0.0644
# Epoch 153/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0306 - val_loss: 0.0715
# Epoch 154/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0305 - val_loss: 0.0665
# Epoch 155/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0307 - val_loss: 0.0709
# Epoch 156/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0307 - val_loss: 0.0698
# Epoch 157/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0306 - val_loss: 0.0679
# Epoch 158/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0305 - val_loss: 0.0632
# Epoch 159/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0306 - val_loss: 0.0756
# Epoch 160/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0306 - val_loss: 0.0651
# Epoch 161/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0306 - val_loss: 0.0683
# Epoch 162/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0305 - val_loss: 0.0768
# Epoch 163/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0303 - val_loss: 0.0645
# Epoch 164/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0303 - val_loss: 0.0639
# Epoch 165/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0303 - val_loss: 0.0642
# Epoch 166/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0307 - val_loss: 0.0673
# Epoch 167/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0302 - val_loss: 0.0622
# Epoch 168/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0302 - val_loss: 0.0642
# Epoch 169/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0304 - val_loss: 0.0669
# Epoch 170/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0301 - val_loss: 0.0726
# Epoch 171/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0302 - val_loss: 0.0647
# Epoch 172/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0302 - val_loss: 0.0599
# Epoch 173/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0301 - val_loss: 0.0624
# Epoch 174/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0300 - val_loss: 0.0609
# Epoch 175/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0303 - val_loss: 0.0743
# Epoch 176/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0299 - val_loss: 0.0677
# Epoch 177/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0301 - val_loss: 0.0626
# Epoch 178/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0299 - val_loss: 0.0659
# Epoch 179/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0297 - val_loss: 0.0681
# Epoch 180/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0297 - val_loss: 0.0650
# Epoch 181/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0299 - val_loss: 0.0616
# Epoch 182/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0299 - val_loss: 0.0692
# Epoch 183/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0299 - val_loss: 0.0746
# Epoch 184/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0298 - val_loss: 0.0594
# Epoch 185/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0299 - val_loss: 0.0630
# Epoch 186/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0300 - val_loss: 0.0666
# Epoch 187/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0298 - val_loss: 0.0586
# Epoch 188/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0297 - val_loss: 0.0606
# Epoch 189/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0298 - val_loss: 0.0622
# Epoch 190/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0299 - val_loss: 0.0692
# Epoch 191/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0297 - val_loss: 0.0656
# Epoch 192/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0295 - val_loss: 0.0623
# Epoch 193/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0296 - val_loss: 0.0673
# Epoch 194/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0298 - val_loss: 0.0751
# Epoch 195/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0296 - val_loss: 0.0655
# Epoch 196/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0306 - val_loss: 0.0676
# Epoch 197/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0298 - val_loss: 0.0627
# Epoch 198/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0295 - val_loss: 0.0608
# Epoch 199/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0295 - val_loss: 0.0638
# Epoch 200/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0296 - val_loss: 0.0647
# Epoch 201/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0295 - val_loss: 0.0607
# Epoch 202/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0297 - val_loss: 0.0680
# Epoch 203/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0294 - val_loss: 0.0622
# Epoch 204/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0294 - val_loss: 0.0615
# Epoch 205/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0296 - val_loss: 0.0639
# Epoch 206/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0295 - val_loss: 0.0647
# Epoch 207/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0293 - val_loss: 0.0731
# Epoch 208/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0294 - val_loss: 0.0650
# Epoch 209/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0291 - val_loss: 0.0621
# Epoch 210/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0294 - val_loss: 0.0671
# Epoch 211/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0295 - val_loss: 0.0638
# Epoch 212/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0293 - val_loss: 0.0833
# Epoch 213/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0291 - val_loss: 0.0702
# Epoch 214/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0291 - val_loss: 0.0677
# Epoch 215/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0291 - val_loss: 0.0625
# Epoch 216/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0296 - val_loss: 0.0627
# Epoch 217/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0291 - val_loss: 0.0759
# Epoch 217: early stopping
# Restoring model weights from the end of the best epoch: 187.

# %%
x_test = np.linspace(-1, 2, 1000)
y_test = x_test + 0.3 * np.sin(2 * np.pi * x_test) + 0.3 * np.sin(4 * np.pi * x_test)

means = []
for _ in range(1000):
    means.append(model(x_test))

y_mean = np.array(means).mean(axis=0)
y_epistemic_variance = np.array(means).std(axis=0) ** 2
y_std = np.sqrt(y_epistemic_variance)


import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.plot(X_train, y_train, 'o', label='Train data', alpha=0.01)
plt.plot(x_test, y_test, 'r', linewidth=3, label="True function", alpha=0.8)
plt.plot(x_test, y_mean, color='b', label='Predictive mean')
plt.fill_between(x_test.flatten(),
                 (y_mean - 1 * y_std).reshape(-1),
                 (y_mean + 1 * y_std).reshape(-1),
                 color='blue', alpha=0.2, label='epistemic uncertainty')
plt.ylim(-2,2)
plt.xlim(-1, 2)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,5))
# plt.plot(X_train, y_train, 'o', label='Train data', alpha=0.01)
plt.plot(x_test, y_test, 'r', linewidth=3, label="True function", alpha=0.8)
plt.plot(x_test, y_mean, color='b', label='Predictive mean')
plt.fill_between(x_test.flatten(),
                 (y_mean - 3 * y_std).reshape(-1),
                 (y_mean + 3 * y_std).reshape(-1),
                 color='blue', alpha=0.2, label='3x epistemic uncertainty')
plt.ylim(-2,2)
plt.xlim(-1, 2)
plt.legend()
plt.show()

# %%
# ------ BAYESIAN GAUSSIAN MIXTURE ------

# %%
tfd = tfp.distributions
tfpl = tfp.layers

batch_num = int(X_train.shape[0] / 128)

scale = X_train.shape[0]


event_shape = [1]
params_size = tfp.layers.MixtureNormal.params_size(2, event_shape)

norm_layer = tf_keras.layers.Normalization(input_shape=(1,))
norm_layer.adapt(X_train.reshape(-1,1))

activation = "relu"
model = tf_keras.Sequential([
    norm_layer,
    tfpl.DenseFlipout(128, activation=activation,
                      kernel_divergence_fn=lambda q,p,ignore: tfp.distributions.kl_divergence(q, p) / scale,
                      bias_divergence_fn=lambda q,p,ignore: tfp.distributions.kl_divergence(q, p) / scale),
    tfpl.DenseFlipout(128, activation=activation,
                      kernel_divergence_fn=lambda q,p,ignore: tfp.distributions.kl_divergence(q, p) / scale,
                      bias_divergence_fn=lambda q,p,ignore: tfp.distributions.kl_divergence(q, p) / scale),
    tfpl.DenseFlipout(128, activation=activation,
                      kernel_divergence_fn=lambda q,p,ignore: tfp.distributions.kl_divergence(q, p) / scale,
                      bias_divergence_fn=lambda q,p,ignore: tfp.distributions.kl_divergence(q, p) / scale),
    tf_keras.layers.Dense(params_size),
    tfp.layers.MixtureNormal(2, event_shape)
])

def negloglik(y_true, y_pred):
    return -y_pred.log_prob(y_true)



boundaries = [150 * batch_num]
values = [0.001, 0.0001]
learning_schedule = tf_keras.optimizers.schedules.PiecewiseConstantDecay(
    boundaries, values)

model.compile(optimizer=tf_keras.optimizers.Adam(learning_rate=learning_schedule), loss=negloglik)
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_3 (Normaliza  (None, 1)                 3
#  tion)
#
#  dense_flipout_9 (DenseFlip  (None, 128)               384
#  out)
#
#  dense_flipout_10 (DenseFli  (None, 128)               32896
#  pout)
#
#  dense_flipout_11 (DenseFli  (None, 128)               32896
#  pout)
#
#  dense_11 (Dense)            (None, 6)                 774
#
#  mixture_normal_2 (MixtureN  ((None, 1),               0
#  ormal)                       (None, 1))
#
# =================================================================
# Total params: 66953 (261.54 KB)
# Trainable params: 66950 (261.52 KB)
# Non-trainable params: 3 (16.00 Byte)
# _________________________________________________________________

# %%
x_test = np.linspace(-0.5, 1.5, 1000)
y_test = x_test + 0.3 * np.sin(2 * np.pi * x_test) + 0.3 * np.sin(4 * np.pi * x_test)


loss_log_dir = "../logs/fit/loss/BNN"
history = model.fit(X_train,y_train, validation_data=(x_test, y_test), epochs=1000, verbose=1, batch_size=128,
                    callbacks=[tf_keras.callbacks.TensorBoard(log_dir=loss_log_dir, histogram_freq=1), tf_keras.callbacks.EarlyStopping(monitor='val_loss',
                                                                                                                                        mode='min',
                                                                                                                                        patience=30,
                                                                                                                                        verbose=1,
                                                                                                                                        start_from_epoch=100,
                                                                                                                                        restore_best_weights=True)])
# Out:
# Epoch 1/1000
# /home/kdrabicki/anaconda3/envs/cpu_env/lib/python3.12/site-packages/tf_keras/src/saving/serialization_lib.py:159: UserWarning: The object being serialized includes a `lambda`. This is unsafe. In order to reload the object, you will have to pass `safe_mode=False` to the loading function. Please avoid using `lambda` in the future, and use named Python functions instead. This is the `lambda` being serialized:         lambda t: MixtureNormal.new(  # pylint: disable=g-long-lambda
#             t, num_components, event_shape, validate_args),
#
#   config_arr = [serialize_keras_object(x) for x in obj]
# 157/157 [==============================] - 2s 3ms/step - loss: 4.1795 - val_loss: 5.8908
# Epoch 2/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 3.6685 - val_loss: 5.1298
# Epoch 3/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 3.4570 - val_loss: 4.7622
# Epoch 4/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 3.2439 - val_loss: 4.9213
# Epoch 5/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 3.0381 - val_loss: 4.3039
# Epoch 6/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 2.8450 - val_loss: 4.1947
# Epoch 7/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 2.6361 - val_loss: 3.4106
# Epoch 8/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 2.4555 - val_loss: 3.4593
# Epoch 9/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 2.2975 - val_loss: 3.2343
# Epoch 10/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 2.1289 - val_loss: 2.9765
# Epoch 11/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.9814 - val_loss: 2.6736
# Epoch 12/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.8523 - val_loss: 2.9963
# Epoch 13/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.7222 - val_loss: 2.4951
# Epoch 14/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.5736 - val_loss: 2.1904
# Epoch 15/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.4684 - val_loss: 2.3531
# Epoch 16/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.3562 - val_loss: 1.9675
# Epoch 17/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.2271 - val_loss: 1.7825
# Epoch 18/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.1253 - val_loss: 1.9646
# Epoch 19/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 1.0197 - val_loss: 1.4824
# Epoch 20/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.9254 - val_loss: 1.4356
# Epoch 21/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.8533 - val_loss: 1.3200
# Epoch 22/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.7536 - val_loss: 1.2156
# Epoch 23/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.6694 - val_loss: 1.2464
# Epoch 24/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.5841 - val_loss: 1.1085
# Epoch 25/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.5092 - val_loss: 1.0307
# Epoch 26/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.4266 - val_loss: 0.7678
# Epoch 27/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.3587 - val_loss: 0.7453
# Epoch 28/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.2805 - val_loss: 0.6265
# Epoch 29/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.2229 - val_loss: 0.6780
# Epoch 30/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.1721 - val_loss: 0.5123
# Epoch 31/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.1082 - val_loss: 0.5737
# Epoch 32/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0554 - val_loss: 0.4486
# Epoch 33/1000
# 157/157 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.4712
# Epoch 34/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.0553 - val_loss: 0.2902
# Epoch 35/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.1020 - val_loss: 0.1990
# Epoch 36/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.1519 - val_loss: 0.2807
# Epoch 37/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.2000 - val_loss: 0.1009
# Epoch 38/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.2318 - val_loss: 0.0525
# Epoch 39/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.2810 - val_loss: 0.0408
# Epoch 40/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.3093 - val_loss: -0.0181
# Epoch 41/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.3542 - val_loss: -0.0275
# Epoch 42/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.3799 - val_loss: -0.1115
# Epoch 43/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.4254 - val_loss: -0.1339
# Epoch 44/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.4581 - val_loss: -0.1064
# Epoch 45/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.4841 - val_loss: -0.1924
# Epoch 46/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.5164 - val_loss: -0.2630
# Epoch 47/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.5382 - val_loss: -0.2205
# Epoch 48/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.5645 - val_loss: -0.2867
# Epoch 49/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.5882 - val_loss: -0.2981
# Epoch 50/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.6078 - val_loss: -0.3563
# Epoch 51/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.6406 - val_loss: -0.3734
# Epoch 52/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.6670 - val_loss: -0.3568
# Epoch 53/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.6831 - val_loss: -0.4008
# Epoch 54/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.6952 - val_loss: -0.4191
# Epoch 55/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.7110 - val_loss: -0.4289
# Epoch 56/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.7234 - val_loss: -0.4059
# Epoch 57/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.7557 - val_loss: -0.4306
# Epoch 58/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.7746 - val_loss: -0.4785
# Epoch 59/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.7921 - val_loss: -0.5742
# Epoch 60/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.8025 - val_loss: -0.5568
# Epoch 61/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.8122 - val_loss: -0.5682
# Epoch 62/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.8341 - val_loss: -0.5443
# Epoch 63/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.8359 - val_loss: -0.6129
# Epoch 64/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.8522 - val_loss: -0.6176
# Epoch 65/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.8752 - val_loss: -0.6005
# Epoch 66/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.8767 - val_loss: -0.6690
# Epoch 67/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.8980 - val_loss: -0.6466
# Epoch 68/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.9125 - val_loss: -0.7093
# Epoch 69/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.9236 - val_loss: -0.6766
# Epoch 70/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.9251 - val_loss: -0.6626
# Epoch 71/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.9375 - val_loss: -0.7277
# Epoch 72/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.9419 - val_loss: -0.7146
# Epoch 73/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.9604 - val_loss: -0.7276
# Epoch 74/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.9700 - val_loss: -0.6634
# Epoch 75/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.9741 - val_loss: -0.7421
# Epoch 76/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.9851 - val_loss: -0.7688
# Epoch 77/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.9927 - val_loss: -0.7574
# Epoch 78/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -0.9991 - val_loss: -0.7491
# Epoch 79/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0028 - val_loss: -0.7255
# Epoch 80/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0128 - val_loss: -0.7489
# Epoch 81/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0202 - val_loss: -0.8352
# Epoch 82/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0179 - val_loss: -0.7633
# Epoch 83/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0308 - val_loss: -0.7901
# Epoch 84/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0449 - val_loss: -0.8266
# Epoch 85/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0411 - val_loss: -0.7994
# Epoch 86/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0467 - val_loss: -0.8330
# Epoch 87/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0575 - val_loss: -0.8094
# Epoch 88/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0656 - val_loss: -0.8209
# Epoch 89/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0705 - val_loss: -0.8137
# Epoch 90/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0714 - val_loss: -0.7952
# Epoch 91/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0755 - val_loss: -0.8985
# Epoch 92/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0916 - val_loss: -0.8549
# Epoch 93/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0884 - val_loss: -0.8805
# Epoch 94/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0878 - val_loss: -0.9139
# Epoch 95/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.0902 - val_loss: -0.8532
# Epoch 96/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1109 - val_loss: -0.8576
# Epoch 97/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1083 - val_loss: -0.8275
# Epoch 98/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1130 - val_loss: -0.8717
# Epoch 99/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1166 - val_loss: -0.8933
# Epoch 100/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1225 - val_loss: -0.8958
# Epoch 101/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1162 - val_loss: -0.8979
# Epoch 102/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1414 - val_loss: -0.9026
# Epoch 103/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1322 - val_loss: -0.8825
# Epoch 104/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1374 - val_loss: -0.9171
# Epoch 105/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1437 - val_loss: -0.8583
# Epoch 106/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1490 - val_loss: -0.9187
# Epoch 107/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1475 - val_loss: -0.9109
# Epoch 108/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1523 - val_loss: -0.8649
# Epoch 109/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1559 - val_loss: -0.9527
# Epoch 110/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1565 - val_loss: -0.8664
# Epoch 111/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1640 - val_loss: -0.9345
# Epoch 112/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1609 - val_loss: -0.9248
# Epoch 113/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1750 - val_loss: -0.8785
# Epoch 114/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1087 - val_loss: -0.8564
# Epoch 115/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1485 - val_loss: -0.8878
# Epoch 116/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1677 - val_loss: -0.9050
# Epoch 117/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1774 - val_loss: -0.9418
# Epoch 118/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1815 - val_loss: -0.9529
# Epoch 119/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1774 - val_loss: -0.8927
# Epoch 120/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1747 - val_loss: -0.9244
# Epoch 121/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1854 - val_loss: -0.8951
# Epoch 122/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1931 - val_loss: -0.9155
# Epoch 123/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1972 - val_loss: -0.8948
# Epoch 124/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1907 - val_loss: -0.8502
# Epoch 125/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2024 - val_loss: -0.9314
# Epoch 126/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2014 - val_loss: -0.8459
# Epoch 127/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1942 - val_loss: -0.6072
# Epoch 128/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2085 - val_loss: -0.8777
# Epoch 129/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1937 - val_loss: -0.9072
# Epoch 130/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2211 - val_loss: -0.9885
# Epoch 131/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2177 - val_loss: -0.9460
# Epoch 132/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2184 - val_loss: -0.9093
# Epoch 133/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2273 - val_loss: -0.9645
# Epoch 134/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2301 - val_loss: -0.9548
# Epoch 135/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2280 - val_loss: -0.9515
# Epoch 136/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2314 - val_loss: -0.9762
# Epoch 137/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2248 - val_loss: -0.9200
# Epoch 138/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2376 - val_loss: -0.9650
# Epoch 139/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2188 - val_loss: -0.9875
# Epoch 140/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2361 - val_loss: -0.9373
# Epoch 141/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2335 - val_loss: -0.9713
# Epoch 142/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2379 - val_loss: -0.9689
# Epoch 143/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2468 - val_loss: -0.9570
# Epoch 144/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2468 - val_loss: -1.0293
# Epoch 145/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2410 - val_loss: -1.0024
# Epoch 146/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2365 - val_loss: -1.0064
# Epoch 147/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2570 - val_loss: -1.0030
# Epoch 148/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2431 - val_loss: -1.0010
# Epoch 149/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2506 - val_loss: -0.9867
# Epoch 150/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2761 - val_loss: -1.0391
# Epoch 151/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2810 - val_loss: -1.0248
# Epoch 152/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2801 - val_loss: -1.0335
# Epoch 153/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2862 - val_loss: -0.9934
# Epoch 154/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2797 - val_loss: -1.0140
# Epoch 155/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2803 - val_loss: -1.0358
# Epoch 156/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2852 - val_loss: -1.0412
# Epoch 157/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.1350 - val_loss: -1.0517
# Epoch 158/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2823 - val_loss: -1.0179
# Epoch 159/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2817 - val_loss: -1.0275
# Epoch 160/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2819 - val_loss: -1.0114
# Epoch 161/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2826 - val_loss: -1.0297
# Epoch 162/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2837 - val_loss: -1.0300
# Epoch 163/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2837 - val_loss: 3.4110
# Epoch 164/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2868 - val_loss: -0.9948
# Epoch 165/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2816 - val_loss: -0.9981
# Epoch 166/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2868 - val_loss: -1.0415
# Epoch 167/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2849 - val_loss: -1.0249
# Epoch 168/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2883 - val_loss: -1.0557
# Epoch 169/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2851 - val_loss: -1.0082
# Epoch 170/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2863 - val_loss: -1.0201
# Epoch 171/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2849 - val_loss: -1.0355
# Epoch 172/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2910 - val_loss: -1.0560
# Epoch 173/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2895 - val_loss: -1.0696
# Epoch 174/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2906 - val_loss: -1.0594
# Epoch 175/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2909 - val_loss: -1.0497
# Epoch 176/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2840 - val_loss: -0.9316
# Epoch 177/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2891 - val_loss: -1.0508
# Epoch 178/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2916 - val_loss: -1.0754
# Epoch 179/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2913 - val_loss: -0.9310
# Epoch 180/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2935 - val_loss: -1.0399
# Epoch 181/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2926 - val_loss: -1.0686
# Epoch 182/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2922 - val_loss: -1.0257
# Epoch 183/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2904 - val_loss: -1.0058
# Epoch 184/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2922 - val_loss: -1.0672
# Epoch 185/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2925 - val_loss: -1.0353
# Epoch 186/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2921 - val_loss: -1.0476
# Epoch 187/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2933 - val_loss: -1.0769
# Epoch 188/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2947 - val_loss: -1.0598
# Epoch 189/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2948 - val_loss: -1.0419
# Epoch 190/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2948 - val_loss: -1.0337
# Epoch 191/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2956 - val_loss: -1.0574
# Epoch 192/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2953 - val_loss: -1.0567
# Epoch 193/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2932 - val_loss: -0.5034
# Epoch 194/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2975 - val_loss: -0.9937
# Epoch 195/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2951 - val_loss: -1.0499
# Epoch 196/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3004 - val_loss: -1.0701
# Epoch 197/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2966 - val_loss: -1.0547
# Epoch 198/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2980 - val_loss: -1.0564
# Epoch 199/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2928 - val_loss: -1.0555
# Epoch 200/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2958 - val_loss: -1.0509
# Epoch 201/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2954 - val_loss: -1.0713
# Epoch 202/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2969 - val_loss: -1.0630
# Epoch 203/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3007 - val_loss: -1.0528
# Epoch 204/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2998 - val_loss: -1.0491
# Epoch 205/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2969 - val_loss: -1.0630
# Epoch 206/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3005 - val_loss: -1.0090
# Epoch 207/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3008 - val_loss: -1.0904
# Epoch 208/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3000 - val_loss: -1.0714
# Epoch 209/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3003 - val_loss: -1.0383
# Epoch 210/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2998 - val_loss: -1.0097
# Epoch 211/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2998 - val_loss: -1.0776
# Epoch 212/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2981 - val_loss: -1.0628
# Epoch 213/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2991 - val_loss: -1.0690
# Epoch 214/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3039 - val_loss: -1.0678
# Epoch 215/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2968 - val_loss: -1.0015
# Epoch 216/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2936 - val_loss: -1.0705
# Epoch 217/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3000 - val_loss: -1.0349
# Epoch 218/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2987 - val_loss: -0.8577
# Epoch 219/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3013 - val_loss: -1.0818
# Epoch 220/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2967 - val_loss: -1.0818
# Epoch 221/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3049 - val_loss: -1.0581
# Epoch 222/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2993 - val_loss: -1.0670
# Epoch 223/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3025 - val_loss: -1.0687
# Epoch 224/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3063 - val_loss: -1.0441
# Epoch 225/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3061 - val_loss: -1.0583
# Epoch 226/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3045 - val_loss: -1.0508
# Epoch 227/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3035 - val_loss: -1.0577
# Epoch 228/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3032 - val_loss: -1.0263
# Epoch 229/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3063 - val_loss: -1.0774
# Epoch 230/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3039 - val_loss: -1.0046
# Epoch 231/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3051 - val_loss: -0.9910
# Epoch 232/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.2842 - val_loss: -1.0332
# Epoch 233/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3020 - val_loss: -1.0402
# Epoch 234/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3080 - val_loss: -1.0731
# Epoch 235/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3063 - val_loss: -1.0716
# Epoch 236/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3060 - val_loss: -0.9227
# Epoch 237/1000
# 157/157 [==============================] - 0s 1ms/step - loss: -1.3057 - val_loss: -1.0779
# Epoch 237: early stopping
# Restoring model weights from the end of the best epoch: 207.

# %%
x_test = np.linspace(-1, 2, 1000)
y_test = x_test + 0.3 * np.sin(2 * np.pi * x_test) + 0.3 * np.sin(4 * np.pi * x_test)

means = []
variances = []
for _ in range(1000):
    dist = model(x_test)
    means.append(dist.mean().numpy())
    variances.append(dist.variance().numpy())

y_mean = np.array(means).mean(axis=0)
y_aleatoric_variance = np.array(variances).mean(axis=0)
y_epistemic_variance = np.array(means).std(axis=0) ** 2
y_std = np.sqrt(y_epistemic_variance)


import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
# plt.plot(X_train, y_train, 'kx', label='Train data')
plt.plot(x_test, y_test, 'r', linewidth=3, label="True function", alpha=0.8)
plt.plot(x_test, y_mean, color='b', label='Predictive mean')
plt.fill_between(x_test.flatten(),
                 (y_mean - 1 * y_std).reshape(-1),
                 (y_mean + 1 * y_std).reshape(-1),
                 color='blue', alpha=0.2, label='epistemic uncertainty')
plt.ylim(-2,2)
plt.xlim(-1, 2)
plt.legend()
plt.show()

# %%
y_std = np.sqrt(y_aleatoric_variance)

plt.figure(figsize=(8,5))
# plt.plot(X_train, y_train, 'kx', label='Train data')
plt.plot(x_test, y_test, 'r', linewidth=3, label="True function", alpha=0.8)
plt.plot(x_test, y_mean, color='b', label='Predictive mean')
plt.fill_between(x_test.flatten(),
                 (y_mean - 1 * y_std).reshape(-1),
                 (y_mean + 1 * y_std).reshape(-1),
                 color='blue', alpha=0.2, label='aleatoric uncertainty')
plt.ylim(-2,2)
plt.xlim(-1, 2)
plt.legend()
plt.show()

# %%
y_std = np.sqrt(y_epistemic_variance + 1.0 * y_aleatoric_variance)
plt.figure(figsize=(8,5))
# plt.plot(X_train, y_train, 'kx', label='Train data')
plt.plot(x_test, y_test, 'r', linewidth=3, label="True function", alpha=0.8)
plt.plot(x_test, y_mean, color='b', label='Predictive mean')
plt.fill_between(x_test.flatten(),
                 (y_mean - 1 * y_std).reshape(-1),
                 (y_mean + 1 * y_std).reshape(-1),
                 color='blue', alpha=0.2, label='Combined uncertainty')
plt.ylim(-2,2)
plt.xlim(-1, 2)
plt.legend()
plt.show()

# %%
# ------ UNCERTAINTY CALCULATION METHOD COMPARISON ------

# %%
num_mc_samples = 1000
num_y_samples  = 1000

all_y_samples = []

for i in range(num_mc_samples):
    pred_dist = model(x_test)
    y_samples = pred_dist.sample(num_y_samples)
    all_y_samples.append(y_samples)   

all_y_samples = tf.stack(all_y_samples, axis=0)
predictive_mean = tf.reduce_mean(all_y_samples, axis=[0,1])   # [batch, output_dim]
predictive_var  = tf.math.reduce_variance(all_y_samples, axis=[0,1])  # [batch, output_dim]
mc_std  = tf.sqrt(predictive_var)

# %%
plt.scatter(x_test, (y_std - mc_std.numpy()) / mc_std.numpy(), s=5)
plt.xlabel("x test")
plt.ylabel("relative std diff")
plt.show()

# %%
plt.hist((y_std - mc_std.numpy()) / mc_std.numpy(), bins=np.arange(-0.2, 0.20, 0.01), histtype="step")
plt.xlabel("relative std diff")
plt.ylabel("counts")
plt.savefig("rel_std_diff_hist.png")
plt.show()

# %%
plt.hist((y_std**2 - predictive_var.numpy()) / predictive_var.numpy(), bins=np.arange(-0.3, 0.3, 0.01), histtype="step")
plt.xlabel("var diff")
plt.ylabel("counts")
plt.show()

# %%
n = 500
print("True value:",y_test[n:n+1].item())
print("Analytical std:", y_std[n:n+1].item())
print("MC std:", mc_std[n:n+1].numpy().item())
dist = model(x_test[n:n+1])
points = np.arange(-1,2,0.01)

log_probs = []
for point in points:
    log_probs.append(dist.log_prob(point))

log_probs = np.exp(np.array(log_probs))
plt.plot(points, log_probs)
plt.show()
# Out:
# True value: 0.5043314712690723
# Analytical std: 0.10468228906393051
# MC std: 0.10804327577352524

# %%
## ---- REDSHIFT DATA ----

# %%
# import importlib

# import data_frame
# import models

# %%
# importlib.reload(data_frame)
# importlib.reload(models)

# filePath = "../KiDS-DR5-WCScut_x_DESI-DR1-small.fits"
# df = data_frame.DataFrame(filePath, "QSO", data_frame.MaxFiller())

# config = {}
# model = models.MLModelContext(strategy=models.BayesianNN(df, config))

# %%
# model.train()

# %%
# scaler = model.strategy.scaler
# X_test, y_test = df.get_random_test_dataset()
# X_faint, y_faint = df.get_faint_test_dataset()
# X_test = scaler.transform(X_test)
# X_faint = scaler.transform(X_faint)

# %%
# sample = 4
# probs = []
# means = []
# variances = []
# for _ in range(8):
#     dist = model.strategy.network(X_faint[sample:sample+1])
#     points = np.arange(0,5,0.01)
#     log_prob = [dist.log_prob(point) for point in points]
#     log_prob = np.array(log_prob)
#     prob = np.exp(log_prob)
#     probs.append(prob)
#     means.append(dist.mean())
#     variances.append(dist.variance())

# probs = np.array(probs).mean(axis=0)
# mean = np.array(means).mean(axis=0)

# plt.plot(points, probs)
# plt.vlines(x=y_faint[sample:sample+1], ymin=0, ymax=probs.max() + 0.1, color="r", linestyles="dashed", label="true")
# plt.vlines(x=mean, ymin=0, ymax=probs.max() + 0.1, color="orange", linestyles="dashed", label="pred")
# plt.legend()
# plt.show()

# print(f"Epistemic error: {np.array(means).std(axis=0).item():.2f}")
# print(f"Aleatoric error: {np.sqrt(np.array(variances).mean(axis=0).item()):.2f}")
