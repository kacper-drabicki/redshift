# %%
import data_loader
import models
import evaluator
import importlib

import os

os.environ["OMP_NUM_THREADS"] = "16"
os.environ["OPENBLAS_NUM_THREADS"] = "16"
os.environ["MKL_NUM_THREADS"] = "16"
os.environ["NUMEXPR_NUM_THREADS"] = "16"
os.environ["VECLIB_MAXIMUM_THREADS"] = "16"

filePath = "KiDS-DR5-WCScut_x_DESI-DR1-small.fits"

# %%
df = data_loader.DataFrame(filePath, "QSO", data_loader.MinFiller())
importlib.reload(models)
model = models.MLModelContext(models.ANNRegressor(df))
model.train()
model.test_predict()
print(evaluator.Evaluator(df).evaluate_metrics())
evaluator.Evaluator(df).redshift_plot()
# Out:
# Epoch 1/300
# /home/kdrabicki/anaconda3/envs/test_env/lib/python3.12/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.6978 - val_loss: 0.1316
# Epoch 2/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1258 - val_loss: 0.1155
# Epoch 3/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1121 - val_loss: 0.1056
# Epoch 4/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1053 - val_loss: 0.1025
# Epoch 5/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0983 - val_loss: 0.1022
# Epoch 6/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0962 - val_loss: 0.1023
# Epoch 7/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0948 - val_loss: 0.1012
# Epoch 8/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0933 - val_loss: 0.0984
# Epoch 9/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0894 - val_loss: 0.1006
# Epoch 10/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0893 - val_loss: 0.0988
# Epoch 11/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0881 - val_loss: 0.0973
# Epoch 12/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0868 - val_loss: 0.0957
# Epoch 13/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0852 - val_loss: 0.0969
# Epoch 14/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0840 - val_loss: 0.0997
# Epoch 15/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0841 - val_loss: 0.0949
# Epoch 16/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0834 - val_loss: 0.0960
# Epoch 17/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0812 - val_loss: 0.0999
# Epoch 18/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0806 - val_loss: 0.0953
# Epoch 19/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0787 - val_loss: 0.0940
# Epoch 20/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0771 - val_loss: 0.0962
# Epoch 21/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0762 - val_loss: 0.0999
# Epoch 22/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0771 - val_loss: 0.0984
# Epoch 23/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0743 - val_loss: 0.0962
# Epoch 24/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0743 - val_loss: 0.1007
# Epoch 25/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0742 - val_loss: 0.1026
# Epoch 26/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0732 - val_loss: 0.0986
# Epoch 27/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0726 - val_loss: 0.1035
# Epoch 28/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0694 - val_loss: 0.0975
# Epoch 29/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0688 - val_loss: 0.0981
# Epoch 30/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0682 - val_loss: 0.1014
# Epoch 31/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0679 - val_loss: 0.0995
# Epoch 32/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0674 - val_loss: 0.1009
# Epoch 33/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0645 - val_loss: 0.0992
# Epoch 34/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0643 - val_loss: 0.1023
# Epoch 35/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0639 - val_loss: 0.1006
# Epoch 36/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0664 - val_loss: 0.1008
# Epoch 37/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0624 - val_loss: 0.1027
# Epoch 38/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0610 - val_loss: 0.1018
# Epoch 39/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0619 - val_loss: 0.1020
# Epoch 40/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0594 - val_loss: 0.1041
# Epoch 41/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0582 - val_loss: 0.1032
# Epoch 42/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0593 - val_loss: 0.1132
# Epoch 43/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0588 - val_loss: 0.1020
# Epoch 44/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0589 - val_loss: 0.1046
# Epoch 45/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0567 - val_loss: 0.1086
# Epoch 46/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0566 - val_loss: 0.1097
# Epoch 47/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0525 - val_loss: 0.1076
# Epoch 48/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0536 - val_loss: 0.1032
# Epoch 49/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0523 - val_loss: 0.1025
# Epoch 49: early stopping
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# {'MSE': 0.10354525373134765, 'R^2': 0.8107572120140063, 'Redshift error': (0.004581927297806059, 0.1348263816475037)}
# /home/kdrabicki/projekt/models.py:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.1264855  1.555844   0.2747476  ... 2.4507518  1.1756777  0.86234504]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dataFrame.data.loc[indexes, "Z_pred"] = self.network.predict(self.X_test)

# %%
df = data_loader.DataFrame(filePath, "QSO", data_loader.MaxFiller())
importlib.reload(models)
model = models.MLModelContext(models.ANNRegressor(df))
model.train()
model.test_predict()
print(evaluator.Evaluator(df).evaluate_metrics())
evaluator.Evaluator(df).redshift_plot()
# Out:
# Epoch 1/300
# /home/kdrabicki/anaconda3/envs/test_env/lib/python3.12/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.7987 - val_loss: 0.1312
# Epoch 2/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1300 - val_loss: 0.1218
# Epoch 3/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1169 - val_loss: 0.1045
# Epoch 4/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1068 - val_loss: 0.0989
# Epoch 5/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1009 - val_loss: 0.0967
# Epoch 6/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0974 - val_loss: 0.0935
# Epoch 7/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0941 - val_loss: 0.0950
# Epoch 8/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0918 - val_loss: 0.0934
# Epoch 9/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0911 - val_loss: 0.0919
# Epoch 10/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0899 - val_loss: 0.0925
# Epoch 11/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0899 - val_loss: 0.0899
# Epoch 12/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0880 - val_loss: 0.0909
# Epoch 13/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0848 - val_loss: 0.0886
# Epoch 14/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0830 - val_loss: 0.0920
# Epoch 15/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0827 - val_loss: 0.0874
# Epoch 16/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0807 - val_loss: 0.0893
# Epoch 17/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0807 - val_loss: 0.0901
# Epoch 18/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0810 - val_loss: 0.0977
# Epoch 19/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0797 - val_loss: 0.0925
# Epoch 20/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0792 - val_loss: 0.0909
# Epoch 21/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0779 - val_loss: 0.0890
# Epoch 22/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0772 - val_loss: 0.0900
# Epoch 23/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0765 - val_loss: 0.0875
# Epoch 24/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0751 - val_loss: 0.0887
# Epoch 25/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0740 - val_loss: 0.0890
# Epoch 26/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0744 - val_loss: 0.0892
# Epoch 27/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0738 - val_loss: 0.0916
# Epoch 28/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0702 - val_loss: 0.0893
# Epoch 29/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0702 - val_loss: 0.0902
# Epoch 30/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0699 - val_loss: 0.0949
# Epoch 31/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0693 - val_loss: 0.0933
# Epoch 32/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0654 - val_loss: 0.0887
# Epoch 33/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0654 - val_loss: 0.0934
# Epoch 34/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0642 - val_loss: 0.0912
# Epoch 35/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0654 - val_loss: 0.0916
# Epoch 36/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0643 - val_loss: 0.0948
# Epoch 37/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0628 - val_loss: 0.0911
# Epoch 38/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0642 - val_loss: 0.0928
# Epoch 39/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0620 - val_loss: 0.0932
# Epoch 40/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0594 - val_loss: 0.0931
# Epoch 41/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0577 - val_loss: 0.0942
# Epoch 42/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0610 - val_loss: 0.0947
# Epoch 43/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0563 - val_loss: 0.0942
# Epoch 44/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0572 - val_loss: 0.0964
# Epoch 45/300
# 891/891 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0539 - val_loss: 0.0980
# Epoch 45: early stopping
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# {'MSE': 0.10691445871893357, 'R^2': 0.8107915600272336, 'Redshift error': (-0.0006572585224878961, 0.13932658777534448)}
# /home/kdrabicki/projekt/models.py:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.98692447 1.7660677  3.0631855  ... 1.9921908  1.5421356  0.2546103 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dataFrame.data.loc[indexes, "Z_pred"] = self.network.predict(self.X_test)

# %%
df = data_loader.DataFrame(filePath, "QSO", data_loader.MeanFiller())
importlib.reload(models)
model = models.MLModelContext(models.ANNRegressor(df))
model.train()
model.test_predict()
print(evaluator.Evaluator(df).evaluate_metrics())
evaluator.Evaluator(df).redshift_plot()
# Out:
# Epoch 1/300
# /home/kdrabicki/anaconda3/envs/test_env/lib/python3.12/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.7349 - val_loss: 0.1457
# Epoch 2/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1355 - val_loss: 0.1332
# Epoch 3/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1238 - val_loss: 0.1252
# Epoch 4/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1138 - val_loss: 0.1200
# Epoch 5/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1091 - val_loss: 0.1166
# Epoch 6/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1067 - val_loss: 0.1209
# Epoch 7/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1044 - val_loss: 0.1103
# Epoch 8/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1019 - val_loss: 0.1117
# Epoch 9/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0989 - val_loss: 0.1127
# Epoch 10/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0990 - val_loss: 0.1081
# Epoch 11/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0951 - val_loss: 0.1074
# Epoch 12/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0918 - val_loss: 0.1113
# Epoch 13/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0899 - val_loss: 0.1099
# Epoch 14/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0876 - val_loss: 0.1063
# Epoch 15/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0859 - val_loss: 0.1096
# Epoch 16/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0851 - val_loss: 0.1036
# Epoch 17/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0831 - val_loss: 0.1042
# Epoch 18/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0810 - val_loss: 0.1070
# Epoch 19/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0814 - val_loss: 0.1064
# Epoch 20/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0794 - val_loss: 0.1078
# Epoch 21/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0761 - val_loss: 0.1065
# Epoch 22/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0757 - val_loss: 0.1068
# Epoch 23/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0721 - val_loss: 0.1079
# Epoch 24/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0704 - val_loss: 0.1152
# Epoch 25/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0724 - val_loss: 0.1065
# Epoch 26/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0688 - val_loss: 0.1159
# Epoch 27/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0677 - val_loss: 0.1114
# Epoch 28/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0670 - val_loss: 0.1087
# Epoch 29/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0657 - val_loss: 0.1102
# Epoch 30/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0646 - val_loss: 0.1097
# Epoch 31/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0625 - val_loss: 0.1107
# Epoch 32/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0615 - val_loss: 0.1144
# Epoch 33/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0598 - val_loss: 0.1146
# Epoch 34/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0592 - val_loss: 0.1198
# Epoch 35/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0572 - val_loss: 0.1232
# Epoch 36/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0578 - val_loss: 0.1190
# Epoch 37/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0549 - val_loss: 0.1204
# Epoch 38/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0562 - val_loss: 0.1134
# Epoch 39/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0538 - val_loss: 0.1201
# Epoch 40/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0521 - val_loss: 0.1221
# Epoch 41/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0513 - val_loss: 0.1204
# Epoch 42/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0497 - val_loss: 0.1197
# Epoch 43/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0506 - val_loss: 0.1332
# Epoch 44/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0484 - val_loss: 0.1215
# Epoch 45/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0485 - val_loss: 0.1226
# Epoch 46/300
# 886/886 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0488 - val_loss: 0.1212
# Epoch 46: early stopping
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# {'MSE': 0.1177335106332063, 'R^2': 0.7848371681346312, 'Redshift error': (0.018335345439648508, 0.14777367321705517)}
# /home/kdrabicki/projekt/models.py:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.8572468  0.72872347 2.2151763  ... 1.5724475  1.1560637  0.85021216]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dataFrame.data.loc[indexes, "Z_pred"] = self.network.predict(self.X_test)

# %%
df = data_loader.DataFrame(filePath, "QSO", data_loader.MedianFiller())
importlib.reload(models)
model = models.MLModelContext(models.ANNRegressor(df))
model.train()
model.test_predict()
print(evaluator.Evaluator(df).evaluate_metrics())
evaluator.Evaluator(df).redshift_plot()
# Out:
# /home/kdrabicki/anaconda3/envs/test_env/lib/python3.12/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.6862 - val_loss: 0.1362
# Epoch 2/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1367 - val_loss: 0.1239
# Epoch 3/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1247 - val_loss: 0.1175
# Epoch 4/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1162 - val_loss: 0.1127
# Epoch 5/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1111 - val_loss: 0.1085
# Epoch 6/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1091 - val_loss: 0.1077
# Epoch 7/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1042 - val_loss: 0.1081
# Epoch 8/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1007 - val_loss: 0.1046
# Epoch 9/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0997 - val_loss: 0.1049
# Epoch 10/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0970 - val_loss: 0.1049
# Epoch 11/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0968 - val_loss: 0.1117
# Epoch 12/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0923 - val_loss: 0.1014
# Epoch 13/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0909 - val_loss: 0.1045
# Epoch 14/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0873 - val_loss: 0.1022
# Epoch 15/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0864 - val_loss: 0.1004
# Epoch 16/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0865 - val_loss: 0.1006
# Epoch 17/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0824 - val_loss: 0.1033
# Epoch 18/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0820 - val_loss: 0.1025
# Epoch 19/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0820 - val_loss: 0.1038
# Epoch 20/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0794 - val_loss: 0.1010
# Epoch 21/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0787 - val_loss: 0.1005
# Epoch 22/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0751 - val_loss: 0.1024
# Epoch 23/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0736 - val_loss: 0.1067
# Epoch 24/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0705 - val_loss: 0.1051
# Epoch 25/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0708 - val_loss: 0.1051
# Epoch 26/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0697 - val_loss: 0.1038
# Epoch 27/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0686 - val_loss: 0.1055
# Epoch 28/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0683 - val_loss: 0.1080
# Epoch 29/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0662 - val_loss: 0.1091
# Epoch 30/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0650 - val_loss: 0.1060
# Epoch 31/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0629 - val_loss: 0.1042
# Epoch 32/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0629 - val_loss: 0.1070
# Epoch 33/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0604 - val_loss: 0.1063
# Epoch 34/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0595 - val_loss: 0.1104
# Epoch 35/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0585 - val_loss: 0.1103
# Epoch 36/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0578 - val_loss: 0.1122
# Epoch 37/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0569 - val_loss: 0.1101
# Epoch 38/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0545 - val_loss: 0.1114
# Epoch 39/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0528 - val_loss: 0.1097
# Epoch 40/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0517 - val_loss: 0.1140
# Epoch 41/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0519 - val_loss: 0.1158
# Epoch 42/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0516 - val_loss: 0.1115
# Epoch 43/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0494 - val_loss: 0.1132
# Epoch 44/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0515 - val_loss: 0.1136
# Epoch 45/300
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0481 - val_loss: 0.1159
# Epoch 45: early stopping
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step
# {'MSE': 0.12454548253280168, 'R^2': 0.7731833373858401, 'Redshift error': (0.021349674019114383, 0.14971384369739454)}
# /home/kdrabicki/projekt/models.py:75: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.5678561 1.8787602 1.368501  ... 0.5859932 1.1971822 1.5288881]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dataFrame.data.loc[indexes, "Z_pred"] = self.network.predict(self.X_test)

# %%
df = data_loader.DataFrame(filePath, "GALAXY", data_loader.MinFiller())
importlib.reload(models)
model = models.MLModelContext(models.ANNRegressor(df))
model.train()
model.test_predict()
print(evaluator.Evaluator(df).evaluate_metrics())
evaluator.Evaluator(df).redshift_plot()
# Out:
# /home/kdrabicki/projekt/data_loader.py:72: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.data = self.data.replace(VALUES_TO_FILL, np.nan)
# /home/kdrabicki/anaconda3/envs/test_env/lib/python3.12/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 10887/10887 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 0.0425 - val_loss: 0.0273
# Epoch 2/300
# 10887/10887 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 0.0276 - val_loss: 0.0272
# Epoch 3/300
# 10887/10887 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 0.0269 - val_loss: 0.0271
# Epoch 4/300
# 10887/10887 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 0.0265 - val_loss: 0.0264
# Epoch 5/300
# 10887/10887 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 0.0263 - val_loss: 0.0261
# Epoch 6/300
# 10887/10887 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 0.0260 - val_loss: 0.0260
# Epoch 7/300
# 10887/10887 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 0.0258 - val_loss: 0.0264
# Epoch 8/300
# 10887/10887 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 0.0260 - val_loss: 0.0259
# Epoch 9/300
# 10887/10887 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 0.0257 - val_loss: 0.0259
# Epoch 10/300
# 10887/10887 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 0.0255 - val_loss: 0.0256
# Epoch 11/300
# 10887/10887 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 0.0254 - val_loss: 0.0257
# Epoch 12/300
# 10887/10887 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 0.0255 - val_loss: 0.0255
# Epoch 13/300
# 10887/10887 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 0.0252 - val_loss: 0.0261
# Epoch 14/300
#   617/10887 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 0.0261
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       2 importlib.reload(models)
#       3 model = models.MLModelContext(models.ANNRegressor(df))
# ----> 4 model.train()
#       5 model.test_predict()
#       6 print(evaluator.Evaluator(df).evaluate_metrics())
#
# File ~/projekt/models.py:88, in train(self)
#      87 def test_predict(self):
# ---> 88     self.strategy.test_predict()
#
# File ~/projekt/models.py:69, in ANNRegressor.train(self)
#      66 self.X_train = self.scaler.fit_transform(self.X_train)
#      67 self.X_val = self.scaler.transform(self.X_val)
# ---> 69 self.network.fit(self.X_train, self.y_train, validation_data=(self.X_val, self.y_val), epochs=self.epochs, batch_size=self.batch_size,
#      70                  callbacks=self.callbacks, verbose=1)
#
# File ~/anaconda3/envs/test_env/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/test_env/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:377, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375 for step, iterator in epoch_iterator:
#     376     callbacks.on_train_batch_begin(step)
# --> 377     logs = self.train_function(iterator)
#     378     callbacks.on_train_batch_end(step, logs)
#     379     if self.stop_training:
#
# File ~/anaconda3/envs/test_env/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:223, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     221     if not opt_outputs.has_value():
#     222         raise StopIteration
# --> 223     return opt_outputs.get_value()
#     224 else:
#     225     for step, data in zip(
#     226         range(self.steps_per_execution), iterator
#     227     ):
#
# File ~/anaconda3/envs/test_env/lib/python3.12/site-packages/tensorflow/python/data/ops/optional_ops.py:185, in _OptionalImpl.get_value(self, name)
#     180 def get_value(self, name=None):
#     181   # TODO(b/110122868): Consolidate the restructuring logic with similar logic
#     182   # in `Iterator.get_next()` and `StructuredFunctionWrapper`.
#     183   with ops.name_scope(name, "OptionalGetValue",
#     184                       [self._variant_tensor]) as scope:
# --> 185     with ops.colocate_with(self._variant_tensor):
#     186       result = gen_optional_ops.optional_get_value(
#     187           self._variant_tensor,
#     188           name=scope,
#     189           output_types=structure.get_flat_tensor_types(self._element_spec),
#     190           output_shapes=structure.get_flat_tensor_shapes(self._element_spec),
#     191       )
#     192     # NOTE: We do not colocate the deserialization of composite tensors
#     193     # because not all ops are guaranteed to have non-GPU kernels.
#
# File ~/anaconda3/envs/test_env/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:4523, in colocate_with(op, ignore_existing)
#    4522 def colocate_with(op, ignore_existing=False) -> ContextManager[None]:
# -> 4523   return _colocate_with_for_gradient(op, None, ignore_existing=ignore_existing)
#
# File ~/anaconda3/envs/test_env/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:4504, in _colocate_with_for_gradient(op, gradient_uid, ignore_existing)
#    4502   if not hasattr(op, "device"):
#    4503     op = convert_to_tensor(op)
# -> 4504   return device(op.device)
#    4505 else:
#    4506   return NullContextmanager()
#
# File ~/anaconda3/envs/test_env/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:4409, in device(device_name_or_function)
#    4405   if callable(device_name_or_function):
#    4406     raise RuntimeError(
#    4407         "tf.device does not support functions when eager execution "
#    4408         "is enabled.")
# -> 4409   return context.device(device_name_or_function)
#    4410 elif executing_eagerly_outside_functions():
#    4411   @tf_contextlib.contextmanager
#    4412   def combined(device_name_or_function):
#
# File ~/anaconda3/envs/test_env/lib/python3.12/site-packages/tensorflow/python/eager/context.py:2758, in device(name)
#    2738 """Context-manager to force placement of operations and Tensors on a device.
#    2739
#    2740 Example:
#    (...)   2755   Context manager for setting the device.
#    2756 """
#    2757 ensure_initialized()
# -> 2758 return context().device(name)
#
# File ~/anaconda3/envs/test_env/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1223, in Context.device(self, name)
#    1221 elif pydev.is_device_spec(name):
#    1222   name = name.to_string()
# -> 1223 return _EagerDeviceContext(self, name)
#
# File ~/anaconda3/envs/test_env/lib/python3.12/site-packages/tensorflow/python/eager/context.py:2431, in _EagerDeviceContext.__init__(self, ctx, device_name)
#    2427 """Context-manager forcing placement of ops and Tensors on a device."""
#    2429 __slots__ = ["_device_name", "_ctx", "_stack"]
# -> 2431 def __init__(self, ctx, device_name):
#    2432   self._device_name = device_name
#    2433   self._ctx = ctx
#
# KeyboardInterrupt:

# %%
df = data_loader.DataFrame(filePath, "GALAXY", data_loader.MaxFiller())
importlib.reload(models)
model = models.MLModelContext(models.ANNRegressor(df))
model.train()
model.test_predict()
print(evaluator.Evaluator(df).evaluate_metrics())
evaluator.Evaluator(df).redshift_plot()
# Out:
# /home/kdrabicki/projekt/data_loader.py:72: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.data = self.data.replace(VALUES_TO_FILL, np.nan)
# /home/kdrabicki/projekt/models.py:35: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.27464727 0.04692488 0.272891   ... 0.20048718 0.93943    0.9919632 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dataFrame.data.loc[self.X_test.index, "Z_pred"] = self.model.predict(self.X_test)
# {'MSE': 0.026743401507101278, 'R^2': 0.8540807421573867, 'Redshift error': (0.008801762155850682, 0.103855417512758)}

# %%
df = data_loader.DataFrame(filePath, "GALAXY", data_loader.MeanFiller())
importlib.reload(models)
model = models.MLModelContext(models.ANNRegressor(df))
model.train()
model.test_predict()
print(evaluator.Evaluator(df).evaluate_metrics())
evaluator.Evaluator(df).redshift_plot()
# Out:
# /home/kdrabicki/projekt/data_loader.py:72: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.data = self.data.replace(VALUES_TO_FILL, np.nan)
# /home/kdrabicki/projekt/models.py:35: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.9730482  0.94637513 0.147571   ... 0.09613589 0.19109541 1.1334183 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dataFrame.data.loc[self.X_test.index, "Z_pred"] = self.model.predict(self.X_test)
# {'MSE': 0.026661974806086425, 'R^2': 0.8544110447615071, 'Redshift error': (0.00882189234215501, 0.10323980306620076)}

# %%
df = data_loader.DataFrame(filePath, "GALAXY", data_loader.MedianFiller())
importlib.reload(models)
model = models.MLModelContext(models.ANNRegressor(df))
model.train()
model.test_predict()
print(evaluator.Evaluator(df).evaluate_metrics())
evaluator.Evaluator(df).redshift_plot()
# Out:
# /home/kdrabicki/projekt/data_loader.py:72: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.data = self.data.replace(VALUES_TO_FILL, np.nan)
# /home/kdrabicki/projekt/models.py:35: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.55235267 0.71277875 0.2984257  ... 1.3284528  0.1091598  0.24539241]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.dataFrame.data.loc[self.X_test.index, "Z_pred"] = self.model.predict(self.X_test)
# {'MSE': 0.026747641757470398, 'R^2': 0.8541542134580218, 'Redshift error': (0.008805032443012183, 0.10345608263566414)}
